# %% [markdown]
# ## Linear Regression
# Below is my first attempt at creating a linear regression algorithm. I will be using this Kaggle dataset: https://www.kaggle.com/datasets/saquib7hussain/experience-salary-dataset.
#
# In this project I hope to get an introduction on many machine learning concepts such as:
# - Data Handling
# - Train / Test split
# - Loss Functions
# - Gradient descent
# - Evaluation metrics
#
# In each section of this notebook I will be answer questions which relate to these concepts.

# %% [markdown]
# Section #1, Data Handling
# In this section I will explore more about data handling, specifically, I hope to learn about feature scaling, and train / test split.
#
# Some questions that I will hope to answer:
# - Why is feature scaling important?
# - Why should we train / test split?
#
# I will be answering these by creating different scenarios where I don't implement this functionality and see the difference in output.

# %%
# %pip install pandas
# %pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the data into a pandas DataFrame
dataset = pd.read_csv("Experience-Salary.csv")

# %% [markdown]
# The first thing that I am going to do is plot the data to visualize the relationship between the dependent and indpendent variable.

# %%
dataset
# Out:
#      exp(in months)  salary(in thousands)
# 0         18.290293             16.521825
# 1         17.023407             11.666234
# 2         26.343613             23.167255
# 3         19.105834             20.877145
# 4         27.742516             23.166236
# ..              ...                   ...
# 995       22.161741             24.666502
# 996       32.266497             24.160270
# 997       17.039030             19.903797
# 998       25.222124             21.974413
# 999       16.418028             19.634787
#
# [1000 rows x 2 columns]

# %%
dataset.plot.scatter(x='exp(in months)', y='salary(in thousands)')
# Out:
# <Axes: xlabel='exp(in months)', ylabel='salary(in thousands)'>

# %% [markdown]
# Now what we can draw from this data is that there is a general linear relationship between the independent and dependent variables. There also doesn't seem to be too much outliers in our data.
#
# Now I am going to split this data into two seperate sets, one will be the training set and the other is going to be our test set.
